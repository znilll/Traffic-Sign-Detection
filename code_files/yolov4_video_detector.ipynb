# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib as plt
import time
from keras.models import load_model

# %%
# Perform histogram equalization on the randomly selected image
def equalize(img):
  img = cv2.equalizeHist(img)
  return img

# Convert the randomly selected image to grayscale
def grayscale(img):
  img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  return img

# Perform grayscale conversion, histogram equalization and normalization on the whole dataset
def preprocessing(img):
  img = grayscale(img)
  img = equalize(img)
  img = img/255
  return img

# %%
best_model = load_model('../CNN_model/cnn_classifier.keras')

# %%
# Load weights
path_to_weights = '../yolov4_model/yolov4_tsb_train_best.weights'
# Load configuration file
path_to_cfg = '../yolov4_model/yolov4_tsb_test.cfg'

# Load weights and configuration file into the network
network = cv2.dnn.readNetFromDarknet(path_to_cfg, path_to_weights)

# To use with GPU
network.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV) #OPENCV
network.setPreferableTarget(cv2.dnn.DNN_TARGET_OPENCL_FP16) #OPENCL_FP16

# %%
# Get names of all YOLO v4 layers
layers_all = network.getLayerNames()

# Get only detection layers
output_layers = network.getUnconnectedOutLayers()
layers_names_output = [layers_all[i - 1] for i in output_layers]

# %%
# Load file with the names of traffic signs

labels = pd.read_csv('../data/signnames.csv')
print(labels)
# Out:
#     ClassId                                           SignName
# 0         0                               Speed limit (20km/h)
# 1         1                               Speed limit (30km/h)
# 2         2                               Speed limit (50km/h)
# 3         3                               Speed limit (60km/h)
# 4         4                               Speed limit (70km/h)
# 5         5                               Speed limit (80km/h)
# 6         6                        End of speed limit (80km/h)
# 7         7                              Speed limit (100km/h)
# 8         8                              Speed limit (120km/h)
# 9         9                                         No passing
# 10       10       No passing for vechiles over 3.5 metric tons
# 11       11              Right-of-way at the next intersection
# 12       12                                      Priority road
# 13       13                                              Yield
# 14       14                                               Stop
# 15       15                                        No vechiles
# 16       16           Vechiles over 3.5 metric tons prohibited
# 17       17                                           No entry
# 18       18                                    General caution
# 19       19                        Dangerous curve to the left
# 20       20                       Dangerous curve to the right
# 21       21                                       Double curve
# 22       22                                         Bumpy road
# 23       23                                      Slippery road
# 24       24                          Road narrows on the right
# 25       25                                          Road work
# 26       26                                    Traffic signals
# 27       27                                        Pedestrians
# 28       28                                  Children crossing
# 29       29                                  Bicycles crossing
# 30       30                                 Beware of ice/snow
# 31       31                              Wild animals crossing
# 32       32                End of all speed and passing limits
# 33       33                                   Turn right ahead
# 34       34                                    Turn left ahead
# 35       35                                         Ahead only
# 36       36                               Go straight or right
# 37       37                                Go straight or left
# 38       38                                         Keep right
# 39       39                                          Keep left
# 40       40                               Roundabout mandatory
# 41       41                                  End of no passing
# 42       42  End of no passing by vechiles over 3.5 metric ...

# %%
# Minimum probability to eliminate weak detections

probability_minimum = 0.6

# Set threshold to filter weak bounding boxes by non-maximum suppression
threshold = 0.4

# Generate colours for bounding boxes
colours = np.random.randint(0, 255, size=(len(labels), 3), dtype='uint8')

# %%
video = cv2.VideoCapture('../data/Filmim.mp4')
# Check if the video capture is opened successfully
if video.isOpened():
    print("Video capture opened successfully.")
    # Get spatial dimensions of the frames
    w = int(video.get(3))
    h = int(video.get(4))
    print(f"Video resolution: {w} x {h}")
else:
    print("Error opening video capture.")
# Writer that will be used to write processed frames
writer = None
# Variables for spatial dimensions of the frames
h, w = None, None

import os

directory_path = '../results/videos'

if os.path.exists(directory_path):
    # Check read permission
    read_permission = os.access(directory_path, os.R_OK)
    print(f"Read Permission: {read_permission}")

    # Check write permission
    write_permission = os.access(directory_path, os.W_OK)
    print(f"Write Permission: {write_permission}")

    # Check execute permission
    execute_permission = os.access(directory_path, os.X_OK)
    print(f"Execute Permission: {execute_permission}")
else:
    print(f"The directory '{directory_path}' does not exist.")
# Out:
# Video capture opened successfully.
# Video resolution: 1920 x 1080
# Read Permission: True
# Write Permission: True
# Execute Permission: True

# %%
# Set default size of plots
plt.rcParams['figure.figsize'] = (3, 3)

# Variable for counting total amount of frames
f = 0

# Variable for counting total processing time
t = 0

# Catch frames in the loop
while True:
    # Capture frames one-by-one
    ret, frame = video.read()

    # If the frame was not retrieved
    if not ret:
        break

    # Get spatial dimensions of the frame for the first time
    if w is None or h is None:
        # Slice two elements from tuple
        h, w = frame.shape[:2]

    # Blob from current frame
    blob = cv2.dnn.blobFromImage(frame, 1 / 255.0, (800, 800), swapRB=True, crop=False)

    # Forward pass with blob through output layers
    network.setInput(blob)
    start = time.time()
    output_from_network = network.forward(layers_names_output)
    end = time.time()

    # Increase counters
    f += 1
    t += end - start

    print('Frame number {0} took {1:.5f} seconds'.format(f, end - start))


    # Lists for detected bounding boxes, confidences, and class's number
    bounding_boxes = []
    confidences = []
    class_numbers = []

    # Go through all output layers after feed forward pass
    for result in output_from_network:
        # Go through all detections from the current output layer
        for detected_objects in result:
            # Get 80 classes probabilities for the current detected object
            scores = detected_objects[5:]
            # Get the index of the class with the maximum value of probability
            class_current = np.argmax(scores)
            # Get the value of probability for the defined class
            confidence_current = scores[class_current]

            # Eliminate weak predictions by minimum probability
            if confidence_current > probability_minimum:
                # Scale bounding box coordinates to the initial frame size
                box_current = detected_objects[0:4] * np.array([w, h, w, h])

                # Get top left corner coordinates
                x_center, y_center, box_width, box_height = box_current
                x_min = int(x_center - (box_width / 2))
                y_min = int(y_center - (box_height / 2))

                # Add results into prepared lists
                bounding_boxes.append([x_min, y_min, int(box_width), int(box_height)])
                confidences.append(float(confidence_current))
                class_numbers.append(class_current)

    # Implement non-maximum suppression of given bounding boxes
    results = cv2.dnn.NMSBoxes(bounding_boxes, confidences, probability_minimum, threshold)

    # Check if there is any detected object been left
    if len(results) > 0:
        # Go through indexes of results
        for i in results.flatten():
            # Bounding box coordinates (width and height)
            x_min, y_min = bounding_boxes[i][0], bounding_boxes[i][1]
            box_width, box_height = bounding_boxes[i][2], bounding_boxes[i][3]

            # Check if the detected sign is a stop sign (assuming class number for stop sign is 14)
            if class_numbers[i] == 14:
                # Write warning text on the frame
                warning_text = "Warning: Stop sign detected!"
                cv2.putText(frame, warning_text, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

            # Cut fragment with traffic sign
            c_ts = frame[y_min:y_min+int(box_height), x_min:x_min+int(box_width), :]
                       
            if c_ts.shape[:1] == (0,) or c_ts.shape[1:2] == (0,):
                pass
            else:

                # Preprocess cut out fragments
                c_ts = np.asarray(c_ts)
                c_ts = cv2.resize(c_ts, (32, 32))
                c_ts = preprocessing(c_ts)
                c_ts = c_ts.reshape(1, 32, 32, 1)

                # Feed to the Clasification model to get predicted label among 43 classes
                scores = best_model.predict(c_ts)

                # Get only class with max confidence
                prediction = np.argmax(scores)

                # Color for current bounding box
                color_box_current = colours[class_numbers[i]].tolist()

                # Draw bounding box on the original current frame
                cv2.rectangle(frame, (x_min, y_min),
                              (x_min + box_width, y_min + box_height),
                              color_box_current, 2)

                # Prepare text with label and confidence for current bounding box
                text_box_current = '{}: {:.4f}'.format(labels['SignName'][prediction], confidences[i])

                # Put text with label and confidence on the original image
                cv2.putText(frame, text_box_current, (x_min, y_min - 5),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.8, color_box_current, 2)


    # Initialize writer only once
    if writer is None:
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')

        # Writing current processed frame into the video file
        writer = cv2.VideoWriter('../results/videos/ızmır.mp4', fourcc, 25,
                                 (frame.shape[1], frame.shape[0]), True)

    # Write processed current frame to the file
    writer.write(frame)


# Release video reader and writer
video.release()
writer.release()
# Out:
# Frame number 1 took 7.39902 seconds
# 1/1 [==============================] - 0s 281ms/step
# 1/1 [==============================] - 0s 29ms/step
# Frame number 2 took 6.63583 seconds
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# Frame number 3 took 7.06622 seconds
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# Frame number 4 took 6.72054 seconds
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# Frame number 5 took 6.79130 seconds
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 6 took 6.63789 seconds
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# Frame number 7 took 6.76080 seconds
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 8 took 6.53318 seconds
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# Frame number 9 took 7.16668 seconds
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# Frame number 10 took 6.46545 seconds
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 11 took 6.39085 seconds
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# Frame number 12 took 6.67266 seconds
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Frame number 13 took 6.36885 seconds
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 14 took 6.31854 seconds
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# Frame number 15 took 6.58787 seconds
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# Frame number 16 took 6.55089 seconds
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# Frame number 17 took 6.43513 seconds
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 18 took 6.34405 seconds
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# Frame number 19 took 6.41676 seconds
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# Frame number 20 took 6.45754 seconds
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 21 took 6.37803 seconds
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# Frame number 22 took 6.40004 seconds
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 23 took 6.39331 seconds
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Frame number 24 took 6.41374 seconds
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# Frame number 25 took 6.44645 seconds
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 26 took 6.37818 seconds
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 27 took 6.41405 seconds
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# Frame number 28 took 6.70065 seconds
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 29 took 6.65267 seconds
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 30 took 6.99824 seconds
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# Frame number 31 took 6.47158 seconds
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 32 took 6.44269 seconds
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# Frame number 33 took 6.46003 seconds
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# Frame number 34 took 6.57749 seconds
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# Frame number 35 took 6.57259 seconds
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 36 took 6.37538 seconds
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 37 took 6.37258 seconds
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# Frame number 38 took 6.33938 seconds
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 39 took 6.37760 seconds
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# Frame number 40 took 6.34130 seconds
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 41 took 6.32581 seconds
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Frame number 42 took 6.28868 seconds
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 43 took 6.33450 seconds
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# Frame number 44 took 6.48704 seconds
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# Frame number 45 took 6.43951 seconds
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Frame number 46 took 6.46105 seconds
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# Frame number 47 took 6.34953 seconds
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Frame number 48 took 6.29721 seconds
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# Frame number 49 took 6.35855 seconds
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# Frame number 50 took 6.34328 seconds
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 51 took 6.33048 seconds
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# Frame number 52 took 6.34674 seconds
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Frame number 53 took 6.31124 seconds
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# Frame number 54 took 6.31160 seconds
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 55 took 6.35621 seconds
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# Frame number 56 took 6.32832 seconds
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# Frame number 57 took 6.62724 seconds
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# Frame number 58 took 7.10627 seconds
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 59 took 6.76058 seconds
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 60 took 6.65627 seconds
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# Frame number 61 took 6.58141 seconds
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 62 took 6.58665 seconds
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# Frame number 63 took 6.58380 seconds
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 50ms/step
# Frame number 64 took 6.74446 seconds
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# Frame number 65 took 6.56319 seconds
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# Frame number 66 took 6.69212 seconds
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# Frame number 67 took 6.75132 seconds
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# Frame number 68 took 6.60589 seconds
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 38ms/step
# Frame number 69 took 6.61377 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# Frame number 70 took 6.55894 seconds
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# Frame number 71 took 6.66153 seconds
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/step
# Frame number 72 took 6.61412 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 73 took 6.67105 seconds
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# Frame number 74 took 6.62571 seconds
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# Frame number 75 took 6.88108 seconds
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 76 took 6.59785 seconds
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 66ms/step
# Frame number 77 took 7.32030 seconds
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 78 took 6.36570 seconds
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 79 took 6.51969 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# Frame number 80 took 6.54867 seconds
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 81 took 6.46159 seconds
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# Frame number 82 took 6.99803 seconds
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# Frame number 83 took 6.48569 seconds
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# Frame number 84 took 6.43888 seconds
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 66ms/step
# Frame number 85 took 6.43404 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# Frame number 86 took 6.44368 seconds
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# Frame number 87 took 6.46846 seconds
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# Frame number 88 took 6.70323 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# Frame number 89 took 6.54109 seconds
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# Frame number 90 took 6.40010 seconds
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# Frame number 91 took 6.68194 seconds
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# Frame number 92 took 6.76417 seconds
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# Frame number 93 took 6.08652 seconds
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# Frame number 94 took 6.00432 seconds
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# Frame number 95 took 6.25193 seconds
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# Frame number 96 took 6.23331 seconds
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 97 took 6.28761 seconds
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# Frame number 98 took 6.07001 seconds
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# Frame number 99 took 5.98894 seconds
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# Frame number 100 took 6.00691 seconds
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# Frame number 101 took 6.12448 seconds
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# Frame number 102 took 6.22525 seconds
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# Frame number 103 took 5.99511 seconds
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# Frame number 104 took 5.95657 seconds
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# Frame number 105 took 5.99773 seconds
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# Frame number 106 took 6.04416 seconds
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# Frame number 107 took 6.04970 seconds
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# Frame number 108 took 6.13441 seconds
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# Frame number 109 took 6.04152 seconds
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# Frame number 110 took 5.98151 seconds
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# Frame number 111 took 6.10855 seconds
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# Frame number 112 took 6.11917 seconds
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# Frame number 113 took 5.95060 seconds
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# Frame number 114 took 6.30126 seconds
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# Frame number 115 took 6.19521 seconds
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# Frame number 116 took 6.19222 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 72ms/step
# Frame number 117 took 6.85146 seconds
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 118 took 6.69118 seconds
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 67ms/step
# Frame number 119 took 6.61409 seconds
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 120 took 6.47726 seconds
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 121 took 6.46426 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 122 took 6.50573 seconds
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 123 took 6.51984 seconds
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 52ms/step
# Frame number 124 took 6.65813 seconds
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# Frame number 125 took 6.53384 seconds
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 126 took 6.53932 seconds
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 127 took 6.49403 seconds
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# Frame number 128 took 6.64261 seconds
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 129 took 6.52833 seconds
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# Frame number 130 took 6.51138 seconds
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# Frame number 131 took 6.46876 seconds
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 64ms/step
# Frame number 132 took 6.75682 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# Frame number 133 took 6.25182 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# Frame number 134 took 6.69390 seconds
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# Frame number 135 took 6.78287 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# Frame number 136 took 6.63209 seconds
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# Frame number 137 took 6.56585 seconds
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# Frame number 138 took 6.51581 seconds
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 42ms/step
# Frame number 139 took 6.57999 seconds
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# Frame number 140 took 6.58720 seconds
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# Frame number 141 took 6.59893 seconds
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 142 took 6.48608 seconds
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 46ms/step
# Frame number 143 took 6.57528 seconds
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 144 took 6.62846 seconds
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 145 took 7.24991 seconds
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# Frame number 146 took 6.36595 seconds
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# Frame number 147 took 6.19916 seconds
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# Frame number 148 took 6.21013 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# Frame number 149 took 6.33808 seconds
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# Frame number 150 took 6.21000 seconds
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# Frame number 151 took 6.37728 seconds
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# Frame number 152 took 6.32985 seconds
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 153 took 6.55579 seconds
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# Frame number 154 took 6.58677 seconds
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 155 took 6.52377 seconds
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 156 took 6.56639 seconds
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# Frame number 157 took 6.59427 seconds
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 158 took 6.71413 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 159 took 6.61970 seconds
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 160 took 6.66399 seconds
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# Frame number 161 took 6.42963 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 51ms/step
# Frame number 162 took 6.56579 seconds
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 163 took 6.66306 seconds
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# Frame number 164 took 6.62804 seconds
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# Frame number 165 took 6.78649 seconds
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 166 took 6.59482 seconds
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 167 took 6.72809 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 168 took 6.86406 seconds
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# Frame number 169 took 6.75909 seconds
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# Frame number 170 took 6.85104 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 171 took 6.72633 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# Frame number 172 took 6.61624 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 173 took 6.53309 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# Frame number 174 took 6.60371 seconds
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 65ms/step
# Frame number 175 took 6.62525 seconds
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 53ms/step
# Frame number 176 took 6.64739 seconds
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# Frame number 177 took 6.65229 seconds
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# Frame number 178 took 6.64597 seconds
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 55ms/step
# Frame number 179 took 6.57398 seconds
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# Frame number 180 took 6.63180 seconds
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# Frame number 181 took 6.81647 seconds
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 44ms/step
# Frame number 182 took 6.71133 seconds
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# Frame number 183 took 6.72975 seconds
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 41ms/step
# Frame number 184 took 6.56638 seconds
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# Frame number 185 took 6.72775 seconds
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 42ms/step
# Frame number 186 took 6.66775 seconds
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# Frame number 187 took 6.68845 seconds
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
